# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
x = np.random.normal(size=100)
sns.distplot(x);

# %%
np.random.seed(88)
x1 = np.random.normal(size=7)
sns.distplot(x1);

# %%
x1
# Out:
# array([ 0.1068843 ,  2.20581524,  0.95656269,  0.0684111 ,  1.06851382,
#         0.99718264, -0.93154792])

# %%
sns.kdeplot(x1)
sns.kdeplot(x, bw=.2, label="bw: 0.2")
sns.kdeplot(x, bw=2, label="bw: 2")
plt.legend();

# %%
a1 = np.array([ 0.1068843 ,  2.20581524,  0.95656269,  0.0684111 ,  1.06851382,
        0.99718264, -0.93154792])
a2 = np.array([0.88988828*10,  0.55423081*10,  0.05819376*10,  0.83899791*10, -0.62403537*10,
        0.27213028*10,  0.65298897*10])
sns.kdeplot(a1, label="a1")
sns.kdeplot(a2, label="a2")
plt.legend();

# %%
data = np.array([[0.1068843, 0.88988828*10], [2.20581524, 2.20581524*10], [0.95656269, 0.95656269*10], [0.0684111, 0.0684111*10], [1.06851382, 1.06851382*10],[0.99718264, 0.99718264*10], [-0.93154792, -0.93154792*10]])
df = pd.DataFrame(data, columns=["x", "y"])
df
# Out:
#           x          y
# 0  0.106884   8.898883
# 1  2.205815  22.058152
# 2  0.956563   9.565627
# 3  0.068411   0.684111
# 4  1.068514  10.685138
# 5  0.997183   9.971826
# 6 -0.931548  -9.315479

# %%
sns.jointplot(x="x", y="y", data=df);
