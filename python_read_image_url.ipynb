# %%
import urllib2
from PIL import Image
# %matplotlib inline

# %%
rose_file = "http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n04971313"
sunflower_file = "http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n11978713"

rose_urls = urllib2.urlopen(rose_file)
for rose_url in rose_urls: 
    print rose_url
    break
    
sunflower_urls = urllib2.urlopen(sunflower_file)
for sunflower_url in sunflower_urls: 
    print sunflower_url
    break
# Out:
# http://farm4.static.flickr.com/3168/3283727603_41835a978a.jpg
#
# http://farm3.static.flickr.com/2408/2262940622_ec850ae796.jpg

# %%
im = Image.open(urllib2.urlopen(rose_url))
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=473x500 at 0x1255EA090>

# %%
im = Image.open(urllib2.urlopen(sunflower_url))
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x500 at 0x1255EA550>
